# %%
import pandas as pd
df = pd.read_csv("uiuc-gpa-dataset-t.csv")
df
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 0      2019  Spring  2019-sp     AAS     100   Intro Asian American Studies
# 1      2019  Spring  2019-sp     AAS     100   Intro Asian American Studies
# 2      2019  Spring  2019-sp     AAS     100   Intro Asian American Studies
# 3      2019  Spring  2019-sp     AAS     100   Intro Asian American Studies
# 4      2019  Spring  2019-sp     AAS     100   Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                            ...
# 48950  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 48951  2010  Summer  2010-su    STAT     440    Statistical Data Management
# 48952  2010  Summer  2010-su     TAM     212          Introductory Dynamics
# 48953  2010  Summer  2010-su     TAM     251   Introductory Solid Mechanics
# 48954  2010  Summer  2010-su     TAM     335   Introductory Fluid Mechanics
#
# ...

# %%
df["Total Students"] = df["A+"] + df['A'] + df["A-"] + df["B+"] + df["B"] + df["B-"] + df["C+"] + df["C"] + df["C-"] + df["D+"] + df["D"] + df["D-"] + df["F"]
df
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 0      2019  Spring  2019-sp     AAS     100   Intro Asian American Studies
# 1      2019  Spring  2019-sp     AAS     100   Intro Asian American Studies
# 2      2019  Spring  2019-sp     AAS     100   Intro Asian American Studies
# 3      2019  Spring  2019-sp     AAS     100   Intro Asian American Studies
# 4      2019  Spring  2019-sp     AAS     100   Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                            ...
# 48950  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 48951  2010  Summer  2010-su    STAT     440    Statistical Data Management
# 48952  2010  Summer  2010-su     TAM     212          Introductory Dynamics
# 48953  2010  Summer  2010-su     TAM     251   Introductory Solid Mechanics
# 48954  2010  Summer  2010-su     TAM     335   Introductory Fluid Mechanics
#
# ...

# %%
df2 = df.groupby("Primary Instructor").agg("mean").reset_index()
df2
# Out:
#            Primary Instructor         Year  Number        A+          A  \
# 0          Aadland, Matthew A  2012.250000   101.0  1.000000   2.750000
# 1          Abbamonte, Peter M  2014.300000   425.6  4.100000  10.100000
# 2                Abbas, Ali E  2012.000000   420.0  2.600000  28.400000
# 3             Abbott, Annie R  2015.600000   253.6  8.400000  10.400000
# 4       Abdel-Khalik, Ahmed R  2013.066667   511.4  0.066667   8.000000
# ...                       ...          ...     ...       ...        ...
# 7476   de Melo Caldas, Renata  2017.400000   452.0  5.400000   7.600000
# 7477   van Doren, Alexandra B  2015.000000   207.0  1.000000  19.666667
# 7478  van der Donk, Wilfred A  2014.625000   384.5  2.000000   8.750000
# 7479     van der Veen, Renske  2017.333333   442.0  1.333333   5.666667
# 7480     van der Zande, Arend  2016.750000   370.0  2.250000  12.750000
#
#              A-         B+          B        B-        C+      C        C-  \
# ...

# %%
gb = pd.read_csv("graybook-t.csv")
gb
# Out:
#                    Employee Name Academic Title  \
# 0                Edakara, Manu I            NaN
# 1           Quarton, John Edward            NaN
# 2          Werpetinski, Valeri A            NaN
# 3     Abdel-Khalik, Ahmed Rashad           PROF
# 4                   Ahmed, Waqar       LECTURER
# ...                          ...            ...
# 3550               Wolfson, Ouri           PROF
# 3551             Wu, Maryalice S  ADJ ASST PROF
# 3552                Yau, Peter M  RES ASST PROF
# 3553                Yodh, Jaya G  RES ASST PROF
# 3554               Zerai, Assata           PROF
#
#                   Primary Job Title Primary College  \
# 0         ASSOC DIR ENTREPRNRL CMTY        Business
# 1      SR DIR INNOVA ENTRPRNRL PRGM        Business
# 2     VST ASSOC DIR, ENTRPRNRL EDUC        Business
# 3                              PROF        Business
# 4                          LECTURER        Business
# ...                             ...             ...
# ...

# %%
group = gb.groupby("Primary Department").agg(["median", "mean", "count"]).reset_index()
group = group[["Primary Department", "Salary"]]
group
# Out:
#                  Primary Department      Salary
#                                          median           mean count
# 0                               ???  120825.305  154959.069576   118
# 1             ADM Institure for PHL   58051.500   58051.500000     2
# 2    Academy Entrepreneurial Ldrshp   71400.000   96060.233333     3
# 3                       Accountancy  210161.000  188585.546119    67
# 4         Aces Info Tech & Cmc Svcs   70582.130   71087.565652    23
# ..                              ...         ...            ...   ...
# 135     Technology Entrepreneur Ctr   61200.000   77353.428571     7
# 136                         Theatre   76343.500   76580.444444    18
# 137       Urban & Regional Planning   88752.000   92951.400000    15
# 138          Veterinary Prog in Agr  149417.760  148582.230000     4
# 139                       eLearning   62934.000   69615.987143    14
#
# [140 rows x 4 columns]

# %%
group.plot.bar(x = "Primary Department", y =[('Salary', 'mean')], figsize = (40, 10))
# Out:
# <AxesSubplot:xlabel='Primary Department'>

# %%
jour = gb[gb["Primary Department"]== "Journalism"]
jour = jour.reset_index()
jour
# Out:
#     index             Employee Name      Academic Title  \
# 0    2310        Benson, Nancy Jane                PROF
# 1    2311     Collins, Janice Marie           ASST PROF
# 2    2312    Craft, Stephanie Lynne                PROF
# 3    2313        Dash, Leon Decosta                PROF
# 4    2314    Erdey, Kenneth Richard                 NaN
# 5    2315        Follis, Jennifer E         SR LECTURER
# 6    2316        Holden, Benjamin A  TEACHING ASST PROF
# 7    2317       Holley, Geralyn Kay            LECTURER
# 8    2318  Houston, Joseph Brantley                PROF
# 9    2319          Johnson, Brian K                PROF
# 10   2320     Layser, Nicole Brooke          ASSOC PROF
# 11   2321          Ledford, Charles          ASSOC PROF
# 12   2322          McDonald, Jean A            LECTURER
# 13   2323             Meyer, Eric K          ASSOC PROF
# 14   2324               Ng, Yee Man           ASST PROF
# 15   2325        Sotirovic, Mirjana          ASSOC PROF
#
# ...

# %%
jour["Primary Job Title"][6] = "Asshole"
jour
# Out:
# /var/folders/lm/1lwdlmhd6kl5mdhrvqdc9_ch0000gn/T/ipykernel_52501/396903865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jour["Primary Job Title"][6] = "Asshole"
#     index             Employee Name      Academic Title  \
# 0    2310        Benson, Nancy Jane                PROF
# 1    2311                      Butt           ASST PROF
# 2    2312    Craft, Stephanie Lynne                PROF
# 3    2313        Dash, Leon Decosta                PROF
# 4    2314    Erdey, Kenneth Richard                 NaN
# 5    2315        Follis, Jennifer E         SR LECTURER
# 6    2316        Holden, Benjamin A  TEACHING ASST PROF
# 7    2317       Holley, Geralyn Kay            LECTURER
# 8    2318  Houston, Joseph Brantley                PROF
# ...

# %% [markdown]
# jour["Employee Name"][6] = "Butt"
# jour

# %%
#dfmi.loc[:, ('one', 'second')] = value
# Out:
#     index             Employee Name      Academic Title  \
# 0    2310        Benson, Nancy Jane                PROF
# 1    2311                      Butt           ASST PROF
# 2    2312    Craft, Stephanie Lynne                PROF
# 3    2313        Dash, Leon Decosta                PROF
# 4    2314    Erdey, Kenneth Richard                 NaN
# 5    2315        Follis, Jennifer E         SR LECTURER
# 6    2316        Holden, Benjamin A  TEACHING ASST PROF
# 7    2317       Holley, Geralyn Kay            LECTURER
# 8    2318  Houston, Joseph Brantley                PROF
# 9    2319          Johnson, Brian K                PROF
# 10   2320     Layser, Nicole Brooke          ASSOC PROF
# 11   2321          Ledford, Charles          ASSOC PROF
# 12   2322          McDonald, Jean A            LECTURER
# 13   2323             Meyer, Eric K          ASSOC PROF
# 14   2324               Ng, Yee Man           ASST PROF
# 15   2325        Sotirovic, Mirjana          ASSOC PROF
#
# ...

# %%
jour
# Out:
#     index             Employee Name      Academic Title  \
# 0    2310        Benson, Nancy Jane                PROF
# 1    2311                      Butt           ASST PROF
# 2    2312    Craft, Stephanie Lynne                PROF
# 3    2313        Dash, Leon Decosta                PROF
# 4    2314    Erdey, Kenneth Richard                 NaN
# 5    2315        Follis, Jennifer E         SR LECTURER
# 6    2316        Holden, Benjamin A  TEACHING ASST PROF
# 7    2317       Holley, Geralyn Kay            LECTURER
# 8    2318  Houston, Joseph Brantley                PROF
# 9    2319          Johnson, Brian K                PROF
# 10   2320     Layser, Nicole Brooke          ASSOC PROF
# 11   2321          Ledford, Charles          ASSOC PROF
# 12   2322          McDonald, Jean A            LECTURER
# 13   2323             Meyer, Eric K          ASSOC PROF
# 14   2324               Ng, Yee Man           ASST PROF
# 15   2325        Sotirovic, Mirjana          ASSOC PROF
#
# ...

# %%
# Out:
# 'Asshole'

# %% [markdown]
# jour[]
