# %%
#importing pandas and reading in the dataset
import pandas as pd
df = pd.read_csv("disney_movies.csv")
df
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# 1       84300000                2188229052
# 2       83320000                2187090808
# 3       65000000                1078510579
# 4       85000000                 920608730
# ..           ...                       ...
# 574     12545979                  12545979
# 575      8874389                   8874389
# 576    232532923                 232532923
# 577    246082029                 246082029
# 578    529483936                 529483936
#
# [579 rows x 6 columns]

# %% [markdown]
# I'm curious- what are the top 10 highest grossing disney movies, both with and without inflation? Does inflation greatly affect the results?

# %%
#without inflation
df_top_10_gross = df.nlargest(10, "total_gross")
df_top_10_gross
# Out:
#                               movie_title release_date      genre mpaa_rating  \
# 564  Star Wars Ep. VII: The Force Awakens   2015-12-18  Adventure       PG-13
# 524                          The Avengers   2012-05-04     Action       PG-13
# 578          Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
# 571                          Finding Dory   2016-06-17  Adventure          PG
# 558               Avengers: Age of Ultron   2015-05-01     Action       PG-13
# 441  Pirates of the Caribbean: Dead Man’…   2006-07-07  Adventure       PG-13
# 179                         The Lion King   1994-06-15  Adventure           G
# 499                           Toy Story 3   2010-06-18  Adventure           G
# 532                            Iron Man 3   2013-05-03     Action       PG-13
# 569            Captain America: Civil War   2016-05-06     Action       PG-13
#
#      total_gross  inflation_adjusted_gross
# 564    936662225                 936662225
# 524    623279547                 660081224
# 578    529483936                 529483936
# 571    486295561                 486295561
# 558    459005868                 459005868
# 441    423315812                 544817142
# 179    422780140                 761640898
# 499    415004880                 443408255
# 532    408992272                 424084233
# 569    408084349                 408084349

# %%
#with inflation
df_top_10_gross_inflation = df.nlargest(10, "inflation_adjusted_gross")
df_top_10_gross_inflation
# Out:
#                               movie_title release_date      genre mpaa_rating  \
# 0         Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                               Pinocchio   1940-02-09  Adventure           G
# 2                                Fantasia   1940-11-13    Musical           G
# 8                          101 Dalmatians   1961-01-25     Comedy           G
# 6                      Lady and the Tramp   1955-06-22      Drama           G
# 3                       Song of the South   1946-11-12  Adventure           G
# 564  Star Wars Ep. VII: The Force Awakens   2015-12-18  Adventure       PG-13
# 4                              Cinderella   1950-02-15      Drama           G
# 13                        The Jungle Book   1967-10-18    Musical   Not Rated
# 179                         The Lion King   1994-06-15  Adventure           G
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# 1       84300000                2188229052
# 2       83320000                2187090808
# 8      153000000                1362870985
# 6       93600000                1236035515
# 3       65000000                1078510579
# 564    936662225                 936662225
# 4       85000000                 920608730
# 13     141843000                 789612346
# 179    422780140                 761640898

# %% [markdown]
# What's the average gross of all Disney movies- both with and without inflation?

# %%
avg_gross = df["total_gross"].mean()
print("The average gross of all Disney movies is $" + str(avg_gross) + ".")
avg_gross_inflation = df["inflation_adjusted_gross"].mean()
print("The average gross of all Disney movies, adjusted for inflation, is $" + str(avg_gross_inflation) + ".")
difference_gross = avg_gross_inflation - avg_gross
print("The average inflation adjusted gross is $" + str(difference_gross) + " greater than the raw gross.")
# Out:
# The average gross of all Disney movies is $64701788.51986183.
# The average gross of all Disney movies, adjusted for inflation, is $118762523.31088082.
# The average inflation adjusted gross is $54060734.79101899 greater than the raw gross.

# %% [markdown]
# From now on, when doing analysis of how much money these movies made, I will use inflation adjusted gross to make sure my assertions are as accurate and fair as possible.

# %% [markdown]
# But how does the MPAA rating of the movie affect the amount of money it makes?

# %% [markdown]
# First, I'll create a separate DataFrame for each MPAA rating, for quick visual comparison and other future uses.

# %%
df_g = df[df["mpaa_rating"] == "G"]
df_g
# Out:
#                          movie_title release_date        genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21      Musical           G
# 1                          Pinocchio   1940-02-09    Adventure           G
# 2                           Fantasia   1940-11-13      Musical           G
# 3                  Song of the South   1946-11-12    Adventure           G
# 4                         Cinderella   1950-02-15        Drama           G
# ..                               ...          ...          ...         ...
# 523                       Chimpanzee   2012-04-20  Documentary           G
# 533              Monsters University   2013-06-21    Adventure           G
# 545                            Bears   2014-04-18  Documentary           G
# 557                   Monkey Kingdom   2015-04-17  Documentary           G
# 568               A Beautiful Planet   2016-04-29  Documentary           G
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# 1       84300000                2188229052
# 2       83320000                2187090808
# 3       65000000                1078510579
# 4       85000000                 920608730
# ..           ...                       ...
# 523     28965459                  30675725
# 533    268488329                 278395641
# 545     17780194                  18346024
# 557     16432322                  16432322
# 568      7895708                   7895708
#
# [86 rows x 6 columns]

# %%
df_pg = df[df["mpaa_rating"] == "PG"]
df_pg
# Out:
#                   movie_title release_date      genre mpaa_rating  \
# 37                     Splash   1984-03-09     Comedy          PG
# 60           3 Men and a Baby   1987-11-25     Comedy          PG
# 64      Return to Snowy River   1988-04-15  Adventure          PG
# 65               Big Business   1988-06-10     Comedy          PG
# 66   Who Framed Roger Rabbit?   1988-06-22     Comedy          PG
# ..                        ...          ...        ...         ...
# 571              Finding Dory   2016-06-17  Adventure          PG
# 572                   The BFG   2016-07-01  Adventure          PG
# 573             Pete’s Dragon   2016-08-12  Adventure          PG
# 575            Queen of Katwe   2016-09-23      Drama          PG
# 577                     Moana   2016-11-23  Adventure          PG
#
#      total_gross  inflation_adjusted_gross
# 37      62599495                 157057661
# 60     167780960                 353334607
# 64      13687027                  28073384
# 65      40150487                  82352451
# 66     154112492                 316250084
# ..           ...                       ...
# 571    486295561                 486295561
# 572     55483770                  55483770
# 573     76233151                  76233151
# 575      8874389                   8874389
# 577    246082029                 246082029
#
# [187 rows x 6 columns]

# %%
df_pg13 = df[df["mpaa_rating"] == "PG-13"]
df_pg13
# Out:
#                               movie_title release_date      genre mpaa_rating  \
# 73                                Beaches   1988-12-21      Drama       PG-13
# 74                        Three Fugitives   1989-01-27     Comedy       PG-13
# 82                          Gross Anatomy   1989-10-20      Drama       PG-13
# 85                                 Stella   1990-02-02      Drama       PG-13
# 90                             Fire Birds   1990-05-24     Action       PG-13
# ..                                    ...          ...        ...         ...
# 564  Star Wars Ep. VII: The Force Awakens   2015-12-18  Adventure       PG-13
# 569            Captain America: Civil War   2016-05-06     Action       PG-13
# 574              The Light Between Oceans   2016-09-02      Drama       PG-13
# 576                        Doctor Strange   2016-11-04  Adventure       PG-13
# 578          Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 73      57041866                 120381757
# 74      40590000                  85757817
# 82      11346186                  23972012
# 85      20062347                  40077147
# 90      14760451                  29485923
# ..           ...                       ...
# 564    936662225                 936662225
# 569    408084349                 408084349
# 574     12545979                  12545979
# 576    232532923                 232532923
# 578    529483936                 529483936
#
# [145 rows x 6 columns]

# %%
df_R = df[df["mpaa_rating"] == "R"]
df_R
# Out:
#                        movie_title release_date   genre mpaa_rating  \
# 45   Down and Out in Beverly Hills   1986-01-31  Comedy           R
# 47                 Ruthless People   1986-06-27  Comedy           R
# 51              The Color of Money   1986-10-17   Drama           R
# 52              Outrageous Fortune   1987-01-30  Comedy           R
# 57                        Stakeout   1987-08-05  Comedy           R
# ..                             ...          ...     ...         ...
# 454                    The Lookout   2007-03-30   Drama           R
# 455                       The Hoax   2007-04-06   Drama           R
# 471            Miracle at St. Anna   2008-09-26   Drama           R
# 517                   Fright Night   2011-08-19  Horror           R
# 536               The Fifth Estate   2013-10-18   Drama           R
#
#      total_gross  inflation_adjusted_gross
# 45      62134225                 141183693
# 47      71624879                 162748712
# 51      52293000                 117957323
# 52      52864741                 113976921
# 57      65673233                 141592160
# ..           ...                       ...
# 454      4600585                   5637048
# 455      7164995                   8779196
# 471      7916887                   9295171
# 517     18298649                  19452402
# 536      3254172                   3374251
#
# [102 rows x 6 columns]

# %%
df_nc17 = df[df["mpaa_rating"] == "NC-17"]
df_nc17
# Out:
# Empty DataFrame
# Columns: [movie_title, release_date, genre, mpaa_rating, total_gross, inflation_adjusted_gross]
# Index: []

# %%
df_not_rated = df[df["mpaa_rating"] == "Not Rated"]
df_not_rated
# Out:
#                   movie_title release_date        genre mpaa_rating  \
# 11                Bon Voyage!   1962-05-17       Comedy   Not Rated
# 13            The Jungle Book   1967-10-18      Musical   Not Rated
# 404  America's Heart and Soul   2004-07-02  Documentary   Not Rated
#
#      total_gross  inflation_adjusted_gross
# 11       9230769                 109581646
# 13     141843000                 789612346
# 404       314000                    426246

# %% [markdown]
# It's also worth noting that PG-13 wasn't a rating given to movies until 1984.

# %% [markdown]
# I want to create a graph that compares the average gross of each rating.

# %%
df_group_rating = df.groupby("mpaa_rating").agg("mean").reset_index()
df_group_rating
# Out:
#   mpaa_rating   total_gross  inflation_adjusted_gross
# 0           G  9.209061e+07              2.912610e+08
# 1   Not Rated  5.046259e+07              2.998734e+08
# 2          PG  7.362521e+07              1.015414e+08
# 3       PG-13  8.118074e+07              1.029486e+08
# 4           R  2.936536e+07              5.530581e+07

# %%
df_group_rating["inflation_adjusted_gross"].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# So is it worth it for dinsey to keep making movies rated PG, PG-13, and R?
# I'm going to run some simulations to find out.

# %% [markdown]
# The simulations will randomly select movies of each rating. However, I'm only going to use movies since July 1, 1984, since that's when the PG-13 rating was first used by the MPAA.
#
# Let's see if I can convert the release date into an integer so I can use it in conditionals.

# %%
#adding new columns to df that describe the release date of the movie in different ways
df["release_year"] = pd.DatetimeIndex(df["release_date"]).year
df["release_month"] = pd.DatetimeIndex(df["release_date"]).month
df["release_day"] = pd.DatetimeIndex(df["release_date"]).day
#This one erases the hyphens in the release date, transforming it into a long number that describes the date using
#the year, month, and day in a way that is still quantifiable.
df["release_number"] = df.apply(lambda row: row["release_date"].replace("-", ""), axis = 1)
df = df.astype({"release_number": int})
df
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross  release_year  release_month  \
# 0      184925485                5228953251          1937             12
# 1       84300000                2188229052          1940              2
# 2       83320000                2187090808          1940             11
# 3       65000000                1078510579          1946             11
# 4       85000000                 920608730          1950              2
# ..           ...                       ...           ...            ...
# 574     12545979                  12545979          2016              9
# 575      8874389                   8874389          2016              9
# 576    232532923                 232532923          2016             11
# 577    246082029                 246082029          2016             11
# 578    529483936                 529483936          2016             12
#
#      release_day  release_number
# 0             21        19371221
# 1              9        19400209
# 2             13        19401113
# 3             12        19461112
# 4             15        19500215
# ..           ...             ...
# 574            2        20160902
# 575           23        20160923
# 576            4        20161104
# 577           23        20161123
# 578           16        20161216
#
# [579 rows x 10 columns]

# %% [markdown]
# Now that I can use release date information as integers, I'm gonna make some cool charts with it- just for fun.

# %%
#Counts the number of movies released in each year
#year_counts = df["release_year"].value_counts()
#df_year_counts = pd.DataFrame(year_counts)
#df_year_counts["year"] = df_year_counts.index
#df_year_counts.sort_values("year").
#df_year_counts.rename(columns = {"release_year": "count"})
#Okay, none of that worked super well. So I'm gonna try to do it by grouping instead.

df_group_year = df.groupby("release_year").agg("count")
df_group_year
# Out:
#               movie_title  release_date  genre  mpaa_rating  total_gross  \
# release_year
# 1937                    1             1      1            1            1
# 1940                    2             2      2            2            2
# 1946                    1             1      1            1            1
# 1950                    1             1      1            1            1
# 1954                    1             1      1            0            1
# 1955                    1             1      1            1            1
# 1959                    1             1      1            0            1
# 1961                    3             3      3            2            3
# 1962                    1             1      1            1            1
# 1963                    1             1      1            0            1
# 1967                    1             1      1            1            1
# 1968                    1             1      1            0            1
# 1970                    2             2      2            1            2
# 1971                    1             1      1            0            1
# 1975                    1             1      1            0            1
# 1977                    4             4      2            0            4
# 1979                    1             1      0            0            1
# 1980                    2             2      0            0            2
# 1981                    4             4      3            0            4
# 1982                    3             3      3            0            3
# 1983                    4             4      4            0            4
# 1984                    2             2      2            1            2
# 1985                    6             6      6            0            6
# 1986                    7             7      7            3            7
# 1987                   10            10     10            4           10
# 1988                   12            12     12            7           12
# 1989                   11            11     11            9           11
# 1990                   15            15     15           14           15
# 1991                   16            16     16           14           16
# 1992                   22            22     19           22           22
# 1993                   27            27     24           27           27
# 1994                   30            30     29           28           30
# 1995                   32            32     32           32           32
# 1996                   28            28     27           28           28
# 1997                   23            23     23           23           23
# 1998                   22            22     22           22           22
# 1999                   21            21     20           21           21
# 2000                   19            19     19           19           19
# 2001                   14            14     13           14           14
# 2002                   22            22     21           21           22
# 2003                   19            19     19           19           19
# 2004                   19            19     19           19           19
# 2005                   17            17     17           17           17
# 2006                   19            19     19           19           19
# 2007                   14            14     14           14           14
# 2008                   13            13     13           13           13
# 2009                   16            16     16           16           16
# 2010                   14            14     14           14           14
# 2011                   14            14     14           14           14
# 2012                   10            10     10           10           10
# 2013                   11            11     11           11           11
# 2014                   12            12     12           12           12
# 2015                   11            11     11           11           11
# 2016                   14            14     14           14           14
#
#               inflation_adjusted_gross  release_month  release_day  \
# release_year
# 1937                                 1              1            1
# 1940                                 2              2            2
# 1946                                 1              1            1
# 1950                                 1              1            1
# 1954                                 1              1            1
# 1955                                 1              1            1
# 1959                                 1              1            1
# 1961                                 3              3            3
# 1962                                 1              1            1
# 1963                                 1              1            1
# 1967                                 1              1            1
# 1968                                 1              1            1
# 1970                                 2              2            2
# 1971                                 1              1            1
# 1975                                 1              1            1
# 1977                                 4              4            4
# 1979                                 1              1            1
# 1980                                 2              2            2
# 1981                                 4              4            4
# 1982                                 3              3            3
# 1983                                 4              4            4
# 1984                                 2              2            2
# 1985                                 6              6            6
# 1986                                 7              7            7
# 1987                                10             10           10
# 1988                                12             12           12
# 1989                                11             11           11
# 1990                                15             15           15
# 1991                                16             16           16
# 1992                                22             22           22
# 1993                                27             27           27
# 1994                                30             30           30
# 1995                                32             32           32
# 1996                                28             28           28
# 1997                                23             23           23
# 1998                                22             22           22
# 1999                                21             21           21
# 2000                                19             19           19
# 2001                                14             14           14
# 2002                                22             22           22
# 2003                                19             19           19
# 2004                                19             19           19
# 2005                                17             17           17
# 2006                                19             19           19
# 2007                                14             14           14
# 2008                                13             13           13
# 2009                                16             16           16
# 2010                                14             14           14
# 2011                                14             14           14
# 2012                                10             10           10
# 2013                                11             11           11
# 2014                                12             12           12
# 2015                                11             11           11
# 2016                                14             14           14
#
#               release_number
# release_year
# 1937                       1
# 1940                       2
# 1946                       1
# 1950                       1
# 1954                       1
# 1955                       1
# 1959                       1
# 1961                       3
# 1962                       1
# 1963                       1
# 1967                       1
# 1968                       1
# 1970                       2
# 1971                       1
# 1975                       1
# 1977                       4
# 1979                       1
# 1980                       2
# 1981                       4
# 1982                       3
# 1983                       4
# 1984                       2
# 1985                       6
# 1986                       7
# 1987                      10
# 1988                      12
# 1989                      11
# 1990                      15
# 1991                      16
# 1992                      22
# 1993                      27
# 1994                      30
# 1995                      32
# 1996                      28
# 1997                      23
# 1998                      22
# 1999                      21
# 2000                      19
# 2001                      14
# 2002                      22
# 2003                      19
# 2004                      19
# 2005                      17
# 2006                      19
# 2007                      14
# 2008                      13
# 2009                      16
# 2010                      14
# 2011                      14
# 2012                      10
# 2013                      11
# 2014                      12
# 2015                      11
# 2016                      14

# %%
#10 years with the highest amount of movies released
df_group_year.nlargest(10, "movie_title")
# Out:
#               movie_title  release_date  genre  mpaa_rating  total_gross  \
# release_year
# 1995                   32            32     32           32           32
# 1994                   30            30     29           28           30
# 1996                   28            28     27           28           28
# 1993                   27            27     24           27           27
# 1997                   23            23     23           23           23
# 1992                   22            22     19           22           22
# 1998                   22            22     22           22           22
# 2002                   22            22     21           21           22
# 1999                   21            21     20           21           21
# 2000                   19            19     19           19           19
#
#               inflation_adjusted_gross  release_month  release_day  \
# release_year
# 1995                                32             32           32
# 1994                                30             30           30
# 1996                                28             28           28
# 1993                                27             27           27
# 1997                                23             23           23
# 1992                                22             22           22
# 1998                                22             22           22
# 2002                                22             22           22
# 1999                                21             21           21
# 2000                                19             19           19
#
#               release_number
# release_year
# 1995                      32
# 1994                      30
# 1996                      28
# 1993                      27
# 1997                      23
# 1992                      22
# 1998                      22
# 2002                      22
# 1999                      21
# 2000                      19

# %%
#I'm going to make a line graph with release_year as the x axis and movie_title as the y axis because
#every movie in this data set has a title, so the count will be accurate. Some other columns are missing
#data for certain movies.
df_group_year.plot.line(y = "movie_title")
# Out:
# <AxesSubplot:xlabel='release_year'>

# %%
df_group_month = df.groupby("release_month").agg("count")
df_group_month
# Out:
#                movie_title  release_date  genre  mpaa_rating  total_gross  \
# release_month
# 1                       38            38     35           34           38
# 2                       44            44     43           38           44
# 3                       61            61     60           54           61
# 4                       50            50     47           46           50
# 5                       41            41     40           39           41
# 6                       50            50     48           45           50
# 7                       44            44     44           36           44
# 8                       49            49     46           43           49
# 9                       43            43     43           40           43
# 10                      50            50     49           47           50
# 11                      59            59     58           54           59
# 12                      50            50     49           47           50
#
#                inflation_adjusted_gross  release_year  release_day  \
# release_month
# 1                                    38            38           38
# 2                                    44            44           44
# 3                                    61            61           61
# 4                                    50            50           50
# 5                                    41            41           41
# 6                                    50            50           50
# 7                                    44            44           44
# 8                                    49            49           49
# 9                                    43            43           43
# 10                                   50            50           50
# 11                                   59            59           59
# 12                                   50            50           50
#
#                release_number
# release_month
# 1                          38
# 2                          44
# 3                          61
# 4                          50
# 5                          41
# 6                          50
# 7                          44
# 8                          49
# 9                          43
# 10                         50
# 11                         59
# 12                         50

# %%
df_group_month.plot.bar(y = "movie_title")
# Out:
# <AxesSubplot:xlabel='release_month'>

# %%
#Selecting movies since July 1, 1984
df_current = df[df["release_number"] >= 19840701]
df_current
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 38                           Country   1984-09-29      Drama         NaN
# 39   Baby: Secret of the Lost Legend   1985-03-22  Adventure         NaN
# 40                      Return to Oz   1985-06-21  Adventure         NaN
# 41                The Black Cauldron   1985-07-24  Adventure         NaN
# 42                My Science Project   1985-08-09     Comedy         NaN
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross  release_year  release_month  \
# 38       8400000                  21075000          1984              9
# 39      14276095                  33900697          1985              3
# 40      10618813                  25215934          1985              6
# 41      21288692                  50553142          1985              7
# 42       4100000                   9736051          1985              8
# ..           ...                       ...           ...            ...
# 574     12545979                  12545979          2016              9
# 575      8874389                   8874389          2016              9
# 576    232532923                 232532923          2016             11
# 577    246082029                 246082029          2016             11
# 578    529483936                 529483936          2016             12
#
#      release_day  release_number
# 38            29        19840929
# 39            22        19850322
# 40            21        19850621
# 41            24        19850724
# 42             9        19850809
# ..           ...             ...
# 574            2        20160902
# 575           23        20160923
# 576            4        20161104
# 577           23        20161123
# 578           16        20161216
#
# [541 rows x 10 columns]

# %% [markdown]
# Now that I've selected movies released since PG-13 first became a rating, I need to narrow it down to movies since then that are also rated either PG-13 or R. After that, I'll run a simulation 10,000 times that takes the average inflation adjusted gross of a random sample of 100 PG-13 or R rated movies.
#
# Hopefully, this will follow a relatively normal distribution. I'll represent it in a histogram.

# %% [markdown]
# I want to see if it's financially worth it for Disney to keep making G rated movies.
# I'll use z scores and cdf functions to see the percentage likeliness of a movie from the more "adult" ratings to make more than a G or PG movies would make, on average.

# %%
#Selecting movies since July 1, 1984 that are rated either G or PG

df_current_kids = df_current[(df_current.mpaa_rating == "G")|(df_current.mpaa_rating == "PG")]
df_current_kids
# Out:
#                   movie_title release_date      genre mpaa_rating  \
# 60           3 Men and a Baby   1987-11-25     Comedy          PG
# 64      Return to Snowy River   1988-04-15  Adventure          PG
# 65               Big Business   1988-06-10     Comedy          PG
# 66   Who Framed Roger Rabbit?   1988-06-22     Comedy          PG
# 71     Ernest Saves Christmas   1988-11-11     Comedy          PG
# ..                        ...          ...        ...         ...
# 571              Finding Dory   2016-06-17  Adventure          PG
# 572                   The BFG   2016-07-01  Adventure          PG
# 573             Pete’s Dragon   2016-08-12  Adventure          PG
# 575            Queen of Katwe   2016-09-23      Drama          PG
# 577                     Moana   2016-11-23  Adventure          PG
#
#      total_gross  inflation_adjusted_gross  release_year  release_month  \
# 60     167780960                 353334607          1987             11
# 64      13687027                  28073384          1988              4
# 65      40150487                  82352451          1988              6
# 66     154112492                 316250084          1988              6
# 71      28202109                  57845202          1988             11
# ..           ...                       ...           ...            ...
# 571    486295561                 486295561          2016              6
# 572     55483770                  55483770          2016              7
# 573     76233151                  76233151          2016              8
# 575      8874389                   8874389          2016              9
# 577    246082029                 246082029          2016             11
#
#      release_day  release_number
# 60            25        19871125
# 64            15        19880415
# 65            10        19880610
# 66            22        19880622
# 71            11        19881111
# ..           ...             ...
# 571           17        20160617
# 572            1        20160701
# 573           12        20160812
# 575           23        20160923
# 577           23        20161123
#
# [263 rows x 10 columns]

# %%
#Selecting movies since July 1, 1984 that are rated either PG-13 or R

df_current_adult = df_current[(df_current.mpaa_rating == "PG-13")|(df_current.mpaa_rating == "R")]
df_current_adult
# Out:
#                               movie_title release_date      genre mpaa_rating  \
# 45          Down and Out in Beverly Hills   1986-01-31     Comedy           R
# 47                        Ruthless People   1986-06-27     Comedy           R
# 51                     The Color of Money   1986-10-17      Drama           R
# 52                     Outrageous Fortune   1987-01-30     Comedy           R
# 57                               Stakeout   1987-08-05     Comedy           R
# ..                                    ...          ...        ...         ...
# 564  Star Wars Ep. VII: The Force Awakens   2015-12-18  Adventure       PG-13
# 569            Captain America: Civil War   2016-05-06     Action       PG-13
# 574              The Light Between Oceans   2016-09-02      Drama       PG-13
# 576                        Doctor Strange   2016-11-04  Adventure       PG-13
# 578          Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross  release_year  release_month  \
# 45      62134225                 141183693          1986              1
# 47      71624879                 162748712          1986              6
# 51      52293000                 117957323          1986             10
# 52      52864741                 113976921          1987              1
# 57      65673233                 141592160          1987              8
# ..           ...                       ...           ...            ...
# 564    936662225                 936662225          2015             12
# 569    408084349                 408084349          2016              5
# 574     12545979                  12545979          2016              9
# 576    232532923                 232532923          2016             11
# 578    529483936                 529483936          2016             12
#
#      release_day  release_number
# 45            31        19860131
# 47            27        19860627
# 51            17        19861017
# 52            30        19870130
# 57             5        19870805
# ..           ...             ...
# 564           18        20151218
# 569            6        20160506
# 574            2        20160902
# 576            4        20161104
# 578           16        20161216
#
# [247 rows x 10 columns]

# %%
#Simulation of avg inflation adjusted gross for PG-13 and R rated movies

data = []
for i in range(10000):
    df_sample = df_current_adult.sample(100)
    mean = df_sample["inflation_adjusted_gross"].mean()
    
    #mean = simulate_average(df_current_adult, "inflation_adjusted_gross", 100)
    d = {"mean inflation adjusted gross": mean}
    data.append(d)
df_simulation_10000 = pd.DataFrame(data)
df_simulation_10000
# Out:
#       mean inflation adjusted gross
# 0                      8.001008e+07
# 1                      6.889040e+07
# 2                      1.012357e+08
# 3                      8.355351e+07
# 4                      6.668048e+07
# ...                             ...
# 9995                   8.225713e+07
# 9996                   9.514835e+07
# 9997                   8.667811e+07
# 9998                   7.038078e+07
# 9999                   8.813827e+07
#
# [10000 rows x 1 columns]

# %%
df_simulation_10000.hist(bins = 100)
# Out:
# array([[<AxesSubplot:title={'center':'mean inflation adjusted gross'}>]],
#       dtype=object)

# %% [markdown]
# Now that we know this follows normal distribution, I can use z scores to find the information I want.

# %%
#Finding z-score zero (mean)

z_0 = df_simulation_10000["mean inflation adjusted gross"].mean()

print(z_0)
# Out:
# 83251659.70938

# %%
#finding standard error of data 

#sd = df_simulation_10000["mean"].std()
#sd
#se = sd / (100 ** 0.5)
#se
sd = df_current_adult["inflation_adjusted_gross"].std()
sd
se = sd / (100 ** 0.5)
se
# Out:
# 11956892.696677737

# %%
#average inflation adjusted gross of kids rated movies since 1984

avg_kids_gross = df_current_kids["inflation_adjusted_gross"].mean()
avg_kids_gross
# Out:
# 111396708.79467681

# %%
#calculating z-score

z_score = (avg_kids_gross - z_0) / se
z_score
# Out:
# 2.3538765295700115

# %%
#How likely is it for a PG-13 or R rated movie to gross more than G and PG rated movies made on average since July 1, 1984?
from scipy.stats import norm
decimal_probability = 1 - norm.cdf(z_score)
decimal_probability
# Out:
# 0.009289390539167885

# %%
#convert to percent

percent_probability = decimal_probability * 100
percent_probability
# Out:
# 0.9289390539167885
