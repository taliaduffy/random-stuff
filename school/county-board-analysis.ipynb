# %%
import pandas as pd
df = pd.read_csv("county-board.csv")
df
# Out:
#      CommitteeID                            CommitteeName  \
# 0          19956                     Friends of Brad Diel
# 1          34816             Traci Nally for County Board
# 2          19988  Prairie Greens of East Central Illinois
# 3          19988  Prairie Greens of East Central Illinois
# 4          19988  Prairie Greens of East Central Illinois
# ..           ...                                      ...
# 96         19988  Prairie Greens of East Central Illinois
# 97         19988  Prairie Greens of East Central Illinois
# 98         19988  Prairie Greens of East Central Illinois
# 99         19988  Prairie Greens of East Central Illinois
# 100        19988  Prairie Greens of East Central Illinois
#
#                                ContributedBy    RcvdDate  Amount  LoanAmount  \
# 0        Urbana Firefighters IAFF Local 1147   10/9/2006   300.0           0
# 1                                 Twelve PAC  10/19/2018  1000.0           0
# ...
