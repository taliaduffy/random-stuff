# %%
import pandas as pd

# %%
df = pd.read_csv("deb-feinen.csv")
df
# Out:
#                                         Contributed By     Amount  \
# 0    15th Congressional District\n1401 Mesquite\nPo...    $200.00
# 1    A.B.D.I. / PAC (Associated Beer Distributors o...  $2,000.00
# 2    A.B.D.I. / PAC (Associated Beer Distributors o...    $500.00
# 3    A.B.D.I. / PAC (Associated Beer Distributors o...    $300.00
# 4        ABATE PAC\n1725 E CR 875 N\nCamargo, IL 61919    $300.00
# ..                                                 ...        ...
# 354  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...    $250.00
# 355  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...    $200.00
# 356  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...    $250.00
# 357  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...    $250.00
# 358  Zachary, Monica L.\n598 Pinecrest Place\nRanto...    $250.00
#
#     Amount Received Date Report Received Date  \
# 0              9/10/2004            4/21/2005
# 1              11/6/2004            4/21/2005
# 2             10/15/2004            4/21/2005
# 3              3/10/2004             8/2/2004
# 4             10/18/2004            4/21/2005
# ..                   ...                  ...
# 354            2/12/2015            4/14/2015
# 355             8/6/2014            10/1/2014
# 356            9/28/2004            4/21/2005
# 357             8/5/2004            4/21/2005
# 358             2/4/2004             8/2/2004
#
#                                            Received By Description  \
# 0       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 1       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 2       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 3       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 4       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# ..                                                 ...         ...
# 354  Individual Contribution\nCitizens for Deborah ...         NaN
# 355  Individual Contribution\nCitizens for Deborah ...         NaN
# 356  Individual Contribution\nCitizens for Deborah ...         NaN
# 357  Individual Contribution\nCitizens for Deborah ...         NaN
# 358  Individual Contribution\nCitizens for Deborah ...         NaN
#
#     Vendor Name Vendor Address
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
# ..          ...            ...
# 354         NaN            NaN
# 355         NaN            NaN
# 356         NaN            NaN
# 357         NaN            NaN
# 358         NaN            NaN
#
# [359 rows x 8 columns]

# %%
#def get_date_info(column_name, og_column, date_info):
    #df[column_name] = pd.DatetimeIndex(data = df[og_column]).date_info

# %%
#extracting date information from date columns
df["Amount received year"] = pd.DatetimeIndex(data = df["Amount Received Date"]).year
df["Amount received month"] = pd.DatetimeIndex(data = df["Amount Received Date"]).month
df["Amount received day"] = pd.DatetimeIndex(data = df["Amount Received Date"]).day
df["Report received year"] = pd.DatetimeIndex(data = df["Report Received Date"]).year
df["Report received month"] = pd.DatetimeIndex(data = df["Report Received Date"]).month
df["Report received day"] = pd.DatetimeIndex(data = df["Report Received Date"]).day
df
# Out:
#                                         Contributed By     Amount  \
# 0    15th Congressional District\n1401 Mesquite\nPo...    $200.00
# 1    A.B.D.I. / PAC (Associated Beer Distributors o...  $2,000.00
# 2    A.B.D.I. / PAC (Associated Beer Distributors o...    $500.00
# 3    A.B.D.I. / PAC (Associated Beer Distributors o...    $300.00
# 4        ABATE PAC\n1725 E CR 875 N\nCamargo, IL 61919    $300.00
# ..                                                 ...        ...
# 354  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...    $250.00
# 355  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...    $200.00
# 356  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...    $250.00
# 357  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...    $250.00
# 358  Zachary, Monica L.\n598 Pinecrest Place\nRanto...    $250.00
#
#     Amount Received Date Report Received Date  \
# 0              9/10/2004            4/21/2005
# 1              11/6/2004            4/21/2005
# 2             10/15/2004            4/21/2005
# 3              3/10/2004             8/2/2004
# 4             10/18/2004            4/21/2005
# ..                   ...                  ...
# 354            2/12/2015            4/14/2015
# 355             8/6/2014            10/1/2014
# 356            9/28/2004            4/21/2005
# 357             8/5/2004            4/21/2005
# 358             2/4/2004             8/2/2004
#
#                                            Received By Description  \
# 0       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 1       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 2       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 3       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 4       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# ..                                                 ...         ...
# 354  Individual Contribution\nCitizens for Deborah ...         NaN
# 355  Individual Contribution\nCitizens for Deborah ...         NaN
# 356  Individual Contribution\nCitizens for Deborah ...         NaN
# 357  Individual Contribution\nCitizens for Deborah ...         NaN
# 358  Individual Contribution\nCitizens for Deborah ...         NaN
#
#     Vendor Name Vendor Address  Amount received year  Amount received month  \
# 0           NaN            NaN                  2004                      9
# 1           NaN            NaN                  2004                     11
# 2           NaN            NaN                  2004                     10
# 3           NaN            NaN                  2004                      3
# 4           NaN            NaN                  2004                     10
# ..          ...            ...                   ...                    ...
# 354         NaN            NaN                  2015                      2
# 355         NaN            NaN                  2014                      8
# 356         NaN            NaN                  2004                      9
# 357         NaN            NaN                  2004                      8
# 358         NaN            NaN                  2004                      2
#
#      Amount received day  Report received year  Report received month  \
# 0                     10                  2005                      4
# 1                      6                  2005                      4
# 2                     15                  2005                      4
# 3                     10                  2004                      8
# 4                     18                  2005                      4
# ..                   ...                   ...                    ...
# 354                   12                  2015                      4
# 355                    6                  2014                     10
# 356                   28                  2005                      4
# 357                    5                  2005                      4
# 358                    4                  2004                      8
#
#      Report received day
# 0                     21
# 1                     21
# 2                     21
# 3                      2
# 4                     21
# ..                   ...
# 354                   14
# 355                    1
# 356                   21
# 357                   21
# 358                    2
#
# [359 rows x 14 columns]

# %%
#Making dollar amount numeric data
df["Amount"] = df["Amount"].replace(to_replace = "\$", value = "", regex = True)
df["Amount"] = df["Amount"].replace(to_replace = ",", value = "", regex = True)
df["Amount"] = df["Amount"].astype(float)
df
# Out:
#                                         Contributed By  Amount  \
# 0    15th Congressional District\n1401 Mesquite\nPo...   200.0
# 1    A.B.D.I. / PAC (Associated Beer Distributors o...  2000.0
# 2    A.B.D.I. / PAC (Associated Beer Distributors o...   500.0
# 3    A.B.D.I. / PAC (Associated Beer Distributors o...   300.0
# 4        ABATE PAC\n1725 E CR 875 N\nCamargo, IL 61919   300.0
# ..                                                 ...     ...
# 354  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...   250.0
# 355  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...   200.0
# 356  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...   250.0
# 357  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...   250.0
# 358  Zachary, Monica L.\n598 Pinecrest Place\nRanto...   250.0
#
#     Amount Received Date Report Received Date  \
# 0              9/10/2004            4/21/2005
# 1              11/6/2004            4/21/2005
# 2             10/15/2004            4/21/2005
# 3              3/10/2004             8/2/2004
# 4             10/18/2004            4/21/2005
# ..                   ...                  ...
# 354            2/12/2015            4/14/2015
# 355             8/6/2014            10/1/2014
# 356            9/28/2004            4/21/2005
# 357             8/5/2004            4/21/2005
# 358             2/4/2004             8/2/2004
#
#                                            Received By Description  \
# 0       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 1       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 2       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 3       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 4       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# ..                                                 ...         ...
# 354  Individual Contribution\nCitizens for Deborah ...         NaN
# 355  Individual Contribution\nCitizens for Deborah ...         NaN
# 356  Individual Contribution\nCitizens for Deborah ...         NaN
# 357  Individual Contribution\nCitizens for Deborah ...         NaN
# 358  Individual Contribution\nCitizens for Deborah ...         NaN
#
#     Vendor Name Vendor Address  Amount received year  Amount received month  \
# 0           NaN            NaN                  2004                      9
# 1           NaN            NaN                  2004                     11
# 2           NaN            NaN                  2004                     10
# 3           NaN            NaN                  2004                      3
# 4           NaN            NaN                  2004                     10
# ..          ...            ...                   ...                    ...
# 354         NaN            NaN                  2015                      2
# 355         NaN            NaN                  2014                      8
# 356         NaN            NaN                  2004                      9
# 357         NaN            NaN                  2004                      8
# 358         NaN            NaN                  2004                      2
#
#      Amount received day  Report received year  Report received month  \
# 0                     10                  2005                      4
# 1                      6                  2005                      4
# 2                     15                  2005                      4
# 3                     10                  2004                      8
# 4                     18                  2005                      4
# ..                   ...                   ...                    ...
# 354                   12                  2015                      4
# 355                    6                  2014                     10
# 356                   28                  2005                      4
# 357                    5                  2005                      4
# 358                    4                  2004                      8
#
#      Report received day
# 0                     21
# 1                     21
# 2                     21
# 3                      2
# 4                     21
# ..                   ...
# 354                   14
# 355                    1
# 356                   21
# 357                   21
# 358                    2
#
# [359 rows x 14 columns]

# %% [markdown]
# ***
# **Timeline of Deb Feinen's political career, to put the following DataFrames into context:**
# - 1992 - 2007: County Board, Member and Vice Chair
# - 2007 - 2015: Champaign City Council, At Large Member
# - 2015 - present: Mayor of Champaign
# ***

# %%
df_year_total = df.groupby("Amount received year").agg("sum").reset_index()
df_year_total
#what was she doing in 2003 / 2004 that required so much money?
# Out:
#     Amount received year    Amount  Amount received month  \
# 0                   2003  22984.08                    475
# 1                   2004  88257.72                    668
# 2                   2005   4721.79                      2
# 3                   2007   8449.00                     69
# 4                   2011   1000.00                      3
# 5                   2013   6680.00                     88
# 6                   2014  17845.00                    399
# 7                   2015  38017.74                    120
# 8                   2017    700.00                     11
# 9                   2018   1500.00                     12
# 10                  2019  28854.51                    154
# 11                  2020    250.00                     12
# 12                  2022   2553.00                     14
# 13                  2023   1000.00                      1
#
#     Amount received day  Report received year  Report received month  \
# 0                   768                 88176                     44
# 1                  1672                196455                    532
# 2                    40                  4010                     14
# 3                   336                 54189                    189
# 4                    15                  2011                      4
# 5                   246                 26169                    121
# 6                   642                110773                    460
# 7                   803                106795                    227
# 8                    45                  4034                     14
# 9                    28                  2019                      1
# 10                  943                119121                    236
# 11                   18                  2021                      1
# 12                   45                  4044                     17
# 13                    2                  2023                      1
#
#     Report received day
# 0                  1320
# 1                  1393
# 2                    12
# 3                   297
# 4                     1
# 5                   100
# 6                   220
# 7                   742
# 8                    15
# 9                     9
# 10                  826
# 11                    5
# 12                    8
# 13                    2

# %%
df_year_count = df.groupby("Amount received year").agg("count").reset_index()
df_year_count
# Out:
#     Amount received year  Contributed By  Amount  Amount Received Date  \
# 0                   2003              44      44                    44
# 1                   2004              98      98                    98
# 2                   2005               2       2                     2
# 3                   2007              27      27                    27
# 4                   2011               1       1                     1
# 5                   2013              13      13                    13
# 6                   2014              55      55                    55
# 7                   2015              53      53                    53
# 8                   2017               2       2                     2
# 9                   2018               1       1                     1
# 10                  2019              59      59                    59
# 11                  2020               1       1                     1
# 12                  2022               2       2                     2
# 13                  2023               1       1                     1
#
#     Report Received Date  Received By  Description  Vendor Name  \
# 0                     44           44            8            4
# 1                     98           98           20           19
# 2                      2            2            2            1
# 3                     27           27            1            1
# 4                      1            1            0            0
# 5                     13           13            1            1
# 6                     55           55            4            3
# 7                     53           53            8            8
# 8                      2            2            0            0
# 9                      1            1            0            0
# 10                    59           59            3            3
# 11                     1            1            0            0
# 12                     2            2            0            0
# 13                     1            1            0            0
#
#     Vendor Address  Amount received month  Amount received day  \
# 0                4                     44                   44
# 1               19                     98                   98
# 2                1                      2                    2
# 3                1                     27                   27
# 4                0                      1                    1
# 5                1                     13                   13
# 6                3                     55                   55
# 7                8                     53                   53
# 8                0                      2                    2
# 9                0                      1                    1
# 10               3                     59                   59
# 11               0                      1                    1
# 12               0                      2                    2
# 13               0                      1                    1
#
#     Report received year  Report received month  Report received day
# 0                     44                     44                   44
# 1                     98                     98                   98
# 2                      2                      2                    2
# 3                     27                     27                   27
# 4                      1                      1                    1
# 5                     13                     13                   13
# 6                     55                     55                   55
# 7                     53                     53                   53
# 8                      2                      2                    2
# 9                      1                      1                    1
# 10                    59                     59                   59
# 11                     1                      1                    1
# 12                     2                      2                    2
# 13                     1                      1                    1

# %%
df_contributors = df.groupby("Contributed By").agg("sum").reset_index()
df_contributors
# Out:
#                                         Contributed By  Amount  \
# 0    15th Congressional District\n1401 Mesquite\nPo...   200.0
# 1    A.B.D.I. / PAC (Associated Beer Distributors o...  2800.0
# 2        ABATE PAC\n1725 E CR 875 N\nCamargo, IL 61919   500.0
# 3    AFL-CIO of Champaign County\n404 West Church S...   250.0
# 4    Adams Outdoor Advertising\n704 N Neil St\nCham...   250.0
# ..                                                 ...     ...
# 226  Weiss, Kenneth S.\n2061 County Road 1400 N\nSt...   250.0
# 227  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...   450.0
# 228  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...   500.0
# 229  Zachary, Monica L.\n598 Pinecrest Place\nRanto...   250.0
# 230  printec\n2602 North Mattis Avenue\nChampaign, ...   510.0
#
#      Amount received year  Amount received month  Amount received day  \
# 0                    2004                      9                   10
# 1                    6012                     24                   31
# 2                    4008                     14                   45
# 3                    2019                      3                   18
# 4                    2007                      3                   26
# ..                    ...                    ...                  ...
# 226                  2003                     12                    2
# 227                  4029                     10                   18
# 228                  4008                     17                   33
# 229                  2004                      2                    4
# 230                  2004                      9                   29
#
#      Report received year  Report received month  Report received day
# 0                    2005                      4                   21
# 1                    6014                     16                   44
# 2                    4009                     12                   23
# 3                    2019                      4                   14
# 4                    2007                      7                   11
# ..                    ...                    ...                  ...
# 226                  2004                      1                   30
# 227                  4029                     14                   15
# 228                  4010                      8                   42
# 229                  2004                      8                    2
# 230                  2005                      4                   21
#
# [231 rows x 8 columns]

# %% [markdown]
# ***
# 231 unique donors; 359 total contributions
# ***

# %%
df_contributors["Contributed By"][1]
# Out:
# 'A.B.D.I. / PAC (Associated Beer Distributors of Illinois)\nP.O. Box 396\nSpringfield, IL 62705'

# %%
df
# Out:
#                                         Contributed By  Amount  \
# 0    15th Congressional District\n1401 Mesquite\nPo...   200.0
# 1    A.B.D.I. / PAC (Associated Beer Distributors o...  2000.0
# 2    A.B.D.I. / PAC (Associated Beer Distributors o...   500.0
# 3    A.B.D.I. / PAC (Associated Beer Distributors o...   300.0
# 4        ABATE PAC\n1725 E CR 875 N\nCamargo, IL 61919   300.0
# ..                                                 ...     ...
# 354  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...   250.0
# 355  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...   200.0
# 356  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...   250.0
# 357  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...   250.0
# 358  Zachary, Monica L.\n598 Pinecrest Place\nRanto...   250.0
#
#     Amount Received Date Report Received Date  \
# 0              9/10/2004            4/21/2005
# 1              11/6/2004            4/21/2005
# 2             10/15/2004            4/21/2005
# 3              3/10/2004             8/2/2004
# 4             10/18/2004            4/21/2005
# ..                   ...                  ...
# 354            2/12/2015            4/14/2015
# 355             8/6/2014            10/1/2014
# 356            9/28/2004            4/21/2005
# 357             8/5/2004            4/21/2005
# 358             2/4/2004             8/2/2004
#
#                                            Received By Description  \
# 0       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 1       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 2       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 3       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 4       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# ..                                                 ...         ...
# 354  Individual Contribution\nCitizens for Deborah ...         NaN
# 355  Individual Contribution\nCitizens for Deborah ...         NaN
# 356  Individual Contribution\nCitizens for Deborah ...         NaN
# 357  Individual Contribution\nCitizens for Deborah ...         NaN
# 358  Individual Contribution\nCitizens for Deborah ...         NaN
#
#     Vendor Name Vendor Address  Amount received year  Amount received month  \
# 0           NaN            NaN                  2004                      9
# 1           NaN            NaN                  2004                     11
# 2           NaN            NaN                  2004                     10
# 3           NaN            NaN                  2004                      3
# 4           NaN            NaN                  2004                     10
# ..          ...            ...                   ...                    ...
# 354         NaN            NaN                  2015                      2
# 355         NaN            NaN                  2014                      8
# 356         NaN            NaN                  2004                      9
# 357         NaN            NaN                  2004                      8
# 358         NaN            NaN                  2004                      2
#
#      Amount received day  Report received year  Report received month  \
# 0                     10                  2005                      4
# 1                      6                  2005                      4
# 2                     15                  2005                      4
# 3                     10                  2004                      8
# 4                     18                  2005                      4
# ..                   ...                   ...                    ...
# 354                   12                  2015                      4
# 355                    6                  2014                     10
# 356                   28                  2005                      4
# 357                    5                  2005                      4
# 358                    4                  2004                      8
#
#      Report received day
# 0                     21
# 1                     21
# 2                     21
# 3                      2
# 4                     21
# ..                   ...
# 354                   14
# 355                    1
# 356                   21
# 357                   21
# 358                    2
#
# [359 rows x 14 columns]

# %%
#Pulling out address data
#also separate column for donor name

df["Address"] = df["Contributed By"].str.split("\n").str[1]
df["Donor"] = df["Contributed By"].str.split("\n").str[0]
df
# Out:
#                                         Contributed By  Amount  \
# 0    15th Congressional District\n1401 Mesquite\nPo...   200.0
# 1    A.B.D.I. / PAC (Associated Beer Distributors o...  2000.0
# 2    A.B.D.I. / PAC (Associated Beer Distributors o...   500.0
# 3    A.B.D.I. / PAC (Associated Beer Distributors o...   300.0
# 4        ABATE PAC\n1725 E CR 875 N\nCamargo, IL 61919   300.0
# ..                                                 ...     ...
# 354  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...   250.0
# 355  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...   200.0
# 356  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...   250.0
# 357  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...   250.0
# 358  Zachary, Monica L.\n598 Pinecrest Place\nRanto...   250.0
#
#     Amount Received Date Report Received Date  \
# 0              9/10/2004            4/21/2005
# 1              11/6/2004            4/21/2005
# 2             10/15/2004            4/21/2005
# 3              3/10/2004             8/2/2004
# 4             10/18/2004            4/21/2005
# ..                   ...                  ...
# 354            2/12/2015            4/14/2015
# 355             8/6/2014            10/1/2014
# 356            9/28/2004            4/21/2005
# 357             8/5/2004            4/21/2005
# 358             2/4/2004             8/2/2004
#
#                                            Received By Description  \
# 0       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 1       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 2       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 3       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 4       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# ..                                                 ...         ...
# 354  Individual Contribution\nCitizens for Deborah ...         NaN
# 355  Individual Contribution\nCitizens for Deborah ...         NaN
# 356  Individual Contribution\nCitizens for Deborah ...         NaN
# 357  Individual Contribution\nCitizens for Deborah ...         NaN
# 358  Individual Contribution\nCitizens for Deborah ...         NaN
#
#     Vendor Name Vendor Address  Amount received year  Amount received month  \
# 0           NaN            NaN                  2004                      9
# 1           NaN            NaN                  2004                     11
# 2           NaN            NaN                  2004                     10
# 3           NaN            NaN                  2004                      3
# 4           NaN            NaN                  2004                     10
# ..          ...            ...                   ...                    ...
# 354         NaN            NaN                  2015                      2
# 355         NaN            NaN                  2014                      8
# 356         NaN            NaN                  2004                      9
# 357         NaN            NaN                  2004                      8
# 358         NaN            NaN                  2004                      2
#
#      Amount received day  Report received year  Report received month  \
# 0                     10                  2005                      4
# 1                      6                  2005                      4
# 2                     15                  2005                      4
# 3                     10                  2004                      8
# 4                     18                  2005                      4
# ..                   ...                   ...                    ...
# 354                   12                  2015                      4
# 355                    6                  2014                     10
# 356                   28                  2005                      4
# 357                    5                  2005                      4
# 358                    4                  2004                      8
#
#      Report received day                Address  \
# 0                     21          1401 Mesquite
# 1                     21           P.O. Box 396
# 2                     21           P.O. Box 396
# 3                      2           P.O. Box 396
# 4                     21        1725 E CR 875 N
# ..                   ...                    ...
# 354                   14          1901 Golfview
# 355                    1          1901 Golfview
# 356                   21  1105 Devonshire Drive
# 357                   21  1105 Devonshire Drive
# 358                    2    598 Pinecrest Place
#
#                                                  Donor
# 0                          15th Congressional District
# 1    A.B.D.I. / PAC (Associated Beer Distributors o...
# 2    A.B.D.I. / PAC (Associated Beer Distributors o...
# 3    A.B.D.I. / PAC (Associated Beer Distributors o...
# 4                                            ABATE PAC
# ..                                                 ...
# 354                                 Williams, Diana S.
# 355                                 Williams, Diana S.
# 356                                   Yarbrough, Roger
# 357                                   Yarbrough, Roger
# 358                                 Zachary, Monica L.
#
# [359 rows x 16 columns]

# %%
df["Donor"].unique()
# Out:
# array(['15th Congressional District',
#        'A.B.D.I. / PAC (Associated Beer Distributors of Illinois)',
#        'ABATE PAC', 'Adams Outdoor Advertising',
#        'AFL-CIO of Champaign County', 'Alliance of American Insurers',
#        'Allied Capital Title', 'Armstrong Lumber',
#        'At&T Illinois Employee PAC',
#        "Attorneys' Title Guaranty Fund Inc.",
#        "Attorney's Title Guaranty Fund, Inc.",
#        "Attorneys' Title Guaranty Fund, Inc. Fed Political Action Committee",
#        'Auth, Mary', 'B & C Development', 'Ballard, Mark',
#        'Barham, James A.', 'Bauer, Wendy', 'Beyers, Roderick (Rick) E.',
#        'Bilger, Kenneth', 'Blager Concrete Co', 'Brantingham, Shirley',
#        'Broeren, Stuart W.', 'Bruno, Thomas A.',
#        'Bussell, Eric and Nancy', 'Cameron, Floyd',
#        'Candlewood Estates LLC', 'Capel, III, James',
#        'Central Il Manufacturing Co', 'Chamley, Joseph',
#        'Champaign Chemical Company',
#        'Champaign County Business Empowered PAC',
#        'Champaign County Chamber of Commerce',
#        'Champaign Firefighters for Good Gov.',
#        'Champaign Firefighters Local 1260',
#        'Champaign Firefighters Local 1260 IAF', 'Chem-PAC (CICI)',
#        'Citizens for Joann Osmond', 'Citizens for Rauschenberger',
#        'Citizens for Rick Winkel', 'Citizens to Elect Tom Cross',
#        'Clarke, Jerome', 'Clausen, L. Dean', 'Cleary, Joseph and Janine',
#        'Clem, Harry E.', 'Cochrane, Scott', 'Combes, Karina K.',
#        'Cowser, Rick', 'Cozad, Gregory D.', 'Crawmer, Daniel',
#        'Cross, James', 'CSX Transportation Inc.', 'CU PLUMBING INC',
#        'CU Under Construction Inc', 'Cunningham Motor Sales Inc.',
#        'Dabrowski, Melinda A.', 'Devonshire Realty', 'Dodds, Jason H.',
#        'Dodds, Jr., Donald C.', 'Dodds, Marci', 'Dodds, Newton H.',
#        'Dorsey, Patrick B.', 'Ducey, Michael', 'Faron Properties',
#        'Faron, James', 'Fiedler, Tom', 'Filson/Gordon Associates',
#        'Fiscella, Phil and Julie', 'Fishel, Lynda',
#        'Fitzgerald, Patrick T.', 'Flessner, Don',
#        'Fox Restaurant Venture L.L.C.', 'Fox, Peter and Kim',
#        'Frank, Linda S.', 'Frasca, Tom & Barb', 'Frederick, Robert',
#        'Frederick, Robert G.', 'Friends for Renee Kosel',
#        'Friends of Chapin Rose', 'Friends of Dan Brady',
#        'Friends of Ginny Holder', 'Friends of Jason Barickman',
#        'Friends of Thomas McNamara', 'Funderburg, Rochelle',
#        'Furtney, Robert D.', 'Gillespie, Tom', 'Goglia, Joe',
#        'Good Government Council', 'Grace, Susan', 'Grandone, Helen F.',
#        'Green, Frederick S.', 'Grey and Associates', 'Haasis, Regina',
#        'Habeeb, Habeeb G.', 'Hannon, Bruce M.',
#        'Harrington Jr., Thomas E.', 'Harrington, Tim and Kristy',
#        'Hartman, Christopher', 'Hartman, Jeffrey', 'Hartman, Michael R.',
#        'Hartman, Stephen', 'Health Alliance Medical Plans',
#        'Hecker, John Z.', 'Heilig, Peggy', 'Herbert, Tracey',
#        'Herriott, David', 'Holt, Dale and Helen', 'Home Builders of ECI',
#        'House Republican Organization', 'Howell, D.D.S., J. Barry',
#        'Hulten, Gordy and Pam', 'ILIPAC',
#        'Illinois Insurance Political Committee',
#        'Illinois Life Insurance Council',
#        'Illinois Liscensed Beverage Association',
#        'Imperial Concrete Co. Inc.',
#        'INA-PAC (Illinois Nurses Association)', 'Jeffrey R. Hartman Co.',
#        "Jill's Creative Expressions", 'Johnson, Aaron and Nicole',
#        'Jones, James', "Jon's Pipe Shop", 'Joy, Richard',
#        'Kanfer, Larry and Alaina', 'Katsinas, Phillip C.',
#        'KEC Design LLC', 'Kennedy, Dana and Michael',
#        'King, Stuart and Teresa', 'Kirby, Leslie and Mike',
#        'Knowles, Marc', 'Kuhl, Dave', 'Laird, Stuart', 'Lamb, Gene',
#        'Lamb, Joseph F.', 'Libman, Sondra', 'LLL Fund', 'Luttrell Design',
#        'Lykin, Gregory', 'MACC of Ill. Inc.',
#        'Madigan, Sinead and Michael', 'Manning, Claire',
#        'Martin, Jane A.', 'Martin, Kevin', 'McDonald, Creg',
#        'McManus, Patricia', 'Meid, Steve', 'Meyer, Carl', 'Meyer, Eric',
#        'Middle Ground PAC', 'Mike Martin Builders LLC',
#        'Miller Enterprises', 'Miller, Jan', 'Miller, Karen',
#        'Miller, Karen K.', 'Miller, Marc', 'Mitchell, Max',
#        'MRH Apartments', 'Nally, Traci E.', 'Neiswender, Brian',
#        'Orange & Blue Distributing Co.', 'PAC 50', 'Parkhill, David',
#        'Patrick Nelson Enterprises Inc', 'Pear Tree Estate', 'Peck, Ed',
#        'Peifer, William', 'Pelafos, Mark & Diane', 'Peters, Todd',
#        'Petroleum Political Education', 'Petry, Joseph',
#        'Phillips, James C.', 'Piper, Debra', 'Pope, Kip and Janet',
#        'Powell, M.D., J. Roger', 'printec', 'Proactive Strategies Inc.',
#        'Professional Independent Insurance Agents of Illinois',
#        'Professional Independent Insurance Agents PAC', 'Radnitzer, Karl',
#        'Ramshaw, Jerald and Christie',
#        'Realtor Political Action Committee', 'Reed, John',
#        'Reimers, Lori A.', 'Republican Party of Champaign County',
#        'Reynolds Towing', 'Roger Yarbrough Trust',
#        'Round Barn Banquet Centre', 'RPAC', 'Ruggieri Team Inc',
#        'Ryle, Lynn E.', 'Sandone, Dawn', 'SBC', 'Schweighart, Gerald J.',
#        'Second Executive Park', 'Sellers, Thomas', 'Shapland, Julia',
#        'Shepherd, William', 'Sholem, David', 'Sholem, David B.',
#        'Sloniger, Grant', 'Smith, Stephen', 'Stewart, Jon D.',
#        'Stumph, Deborah and Brian', 'Taylor Uhe LLC',
#        'The Drawing Card / Susan Huelsing',
#        'Tom Berns for State Representative', 'Tortorelli, Linda',
#        'Town Center 507 LLC', 'Venable, Robert', 'Walsh, Daniel',
#        'Wandell, J.A.', 'Watts, Robert A.', 'Weibl, Richard',
#        'Weiss, Kenneth S.', 'Williams, Diana S.', 'Yarbrough, Roger',
#        'Zachary, Monica L.'], dtype=object)

# %%
df["Donor"][1]
# Out:
# 'A.B.D.I. / PAC (Associated Beer Distributors of Illinois)'

# %%
df_beverage = df[df["Donor"] == "Illinois Liscensed Beverage Association"]
df_beverage
#non profit org!!! Dark money????
# Out:
#                                         Contributed By  Amount  \
# 205  Illinois Liscensed Beverage Association\n1127 ...   500.0
#
#     Amount Received Date Report Received Date  \
# 205             2/6/2019            4/14/2019
#
#                                         Received By Description Vendor Name  \
# 205  Transfer In\nCitizens for Deborah Frank Feinen         NaN         NaN
#
#     Vendor Address  Amount received year  Amount received month  \
# 205            NaN                  2019                      2
#
#      Amount received day  Report received year  Report received month  \
# 205                    6                  2019                      4
#
#      Report received day                   Address  \
# 205                   14  1127 South Second Street
#
#                                        Donor         Report delay months
# 205  Illinois Liscensed Beverage Association  {'Report delay months': 2}

# %%
df_bruno = df[df["Donor"] == "Bruno, Thomas A."]
df_bruno
# Out:
#                                        Contributed By  Amount  \
# 33  Bruno, Thomas A.\n1109 West Park Avenue\nChamp...   125.0
# 34  Bruno, Thomas A.\n1109 West Park Avenue\nChamp...    50.0
#
#    Amount Received Date Report Received Date  \
# 33            12/9/2003            1/30/2004
# 34           10/17/2003            1/30/2004
#
#                                           Received By Description Vendor Name  \
# 33  Individual Contribution\nCitizens for Deborah ...         NaN         NaN
# 34  Individual Contribution\nCitizens for Deborah ...         NaN         NaN
#
#    Vendor Address  Amount received year  Amount received month  \
# 33            NaN                  2003                     12
# 34            NaN                  2003                     10
#
#     Amount received day  Report received year  Report received month  \
# 33                    9                  2004                      1
# 34                   17                  2004                      1
#
#     Report received day                Address             Donor  \
# 33                   30  1109 West Park Avenue  Bruno, Thomas A.
# 34                   30  1109 West Park Avenue  Bruno, Thomas A.
#
#            Report delay months
# 33  {'Report delay months': 1}
# 34  {'Report delay months': 3}

# %%
df_fox_restaurant = df[df["Donor"] == "Fox Restaurant Venture L.L.C."]
df_fox_restaurant
#https://law.justia.com/cases/federal/district-courts/illinois/ilcdce/2:2017cv02104/69413/31/
# Out:
#                                         Contributed By  Amount  \
# 113  Fox Restaurant Venture L.L.C.\nJimmy John's\n1...   250.0
#
#     Amount Received Date Report Received Date  \
# 113           10/30/2003            1/30/2004
#
#                                            Received By Description  \
# 113  Individual Contribution\nCitizens for Deborah ...         NaN
#
#     Vendor Name Vendor Address  Amount received year  Amount received month  \
# 113         NaN            NaN                  2003                     10
#
#      Amount received day  Report received year  Report received month  \
# 113                   30                  2004                      1
#
#      Report received day       Address                          Donor  \
# 113                   30  Jimmy John's  Fox Restaurant Venture L.L.C.
#
#             Report delay months
# 113  {'Report delay months': 3}

# %%
df_ob = df[df["Donor"] == "Orange & Blue Distributing Co."]
df_ob
# Out:
#                                         Contributed By  Amount  \
# 277  Orange & Blue Distributing Co.\n2902 Lager Dri...   200.0
#
#     Amount Received Date Report Received Date  \
# 277            9/23/2004            4/21/2005
#
#                                            Received By Description  \
# 277  Individual Contribution\nCitizens for Deborah ...         NaN
#
#     Vendor Name Vendor Address  Amount received year  Amount received month  \
# 277         NaN            NaN                  2004                      9
#
#      Amount received day  Report received year  Report received month  \
# 277                   23                  2005                      4
#
#      Report received day           Address                           Donor  \
# 277                   21  2902 Lager Drive  Orange & Blue Distributing Co.
#
#             Report delay months
# 277  {'Report delay months': 7}

# %%
df_beer = df[df["Donor"] == "A.B.D.I. / PAC (Associated Beer Distributors of Illinois)"]
df_beer
# Out:
#                                       Contributed By  Amount  \
# 1  A.B.D.I. / PAC (Associated Beer Distributors o...  2000.0
# 2  A.B.D.I. / PAC (Associated Beer Distributors o...   500.0
# 3  A.B.D.I. / PAC (Associated Beer Distributors o...   300.0
#
#   Amount Received Date Report Received Date  \
# 1            11/6/2004            4/21/2005
# 2           10/15/2004            4/21/2005
# 3            3/10/2004             8/2/2004
#
#                                       Received By Description Vendor Name  \
# 1  Transfer In\nCitizens for Deborah Frank Feinen         NaN         NaN
# 2  Transfer In\nCitizens for Deborah Frank Feinen         NaN         NaN
# 3  Transfer In\nCitizens for Deborah Frank Feinen         NaN         NaN
#
#   Vendor Address  Amount received year  Amount received month  \
# 1            NaN                  2004                     11
# 2            NaN                  2004                     10
# 3            NaN                  2004                      3
#
#    Amount received day  Report received year  Report received month  \
# 1                    6                  2005                      4
# 2                   15                  2005                      4
# 3                   10                  2004                      8
#
#    Report received day       Address  \
# 1                   21  P.O. Box 396
# 2                   21  P.O. Box 396
# 3                    2  P.O. Box 396
#
#                                                Donor
# 1  A.B.D.I. / PAC (Associated Beer Distributors o...
# 2  A.B.D.I. / PAC (Associated Beer Distributors o...
# 3  A.B.D.I. / PAC (Associated Beer Distributors o...

# %%
df_ramshaw = df[df["Donor"] == "Ramshaw, Jerald and Christie"]
df_ramshaw
# Out:
#                                         Contributed By  Amount  \
# 303  Ramshaw, Jerald and Christie\nP.O. Box 680\nCh...   500.0
#
#     Amount Received Date Report Received Date  \
# 303            2/28/2019            4/14/2019
#
#                                            Received By Description  \
# 303  Individual Contribution\nCitizens for Deborah ...         NaN
#
#     Vendor Name Vendor Address  Amount received year  Amount received month  \
# 303         NaN            NaN                  2019                      2
#
#      Amount received day  Report received year  Report received month  \
# 303                   28                  2019                      4
#
#      Report received day       Address                         Donor  \
# 303                   14  P.O. Box 680  Ramshaw, Jerald and Christie
#
#             Report delay months
# 303  {'Report delay months': 2}

# %%
#calculating the delay between receiving the money and reporting the money

data = []
for i in range (len(df)):
    difference = df["Report received month"][i] - df["Amount received month"][i]
    if difference < 0: 
        delay = 12 + difference
    else: 
        delay = difference
    d = {"Report delay months" : delay}
    data.append(d)
df["Report delay months"] = data

# %%
df
# Out:
#                                         Contributed By  Amount  \
# 0    15th Congressional District\n1401 Mesquite\nPo...   200.0
# 1    A.B.D.I. / PAC (Associated Beer Distributors o...  2000.0
# 2    A.B.D.I. / PAC (Associated Beer Distributors o...   500.0
# 3    A.B.D.I. / PAC (Associated Beer Distributors o...   300.0
# 4        ABATE PAC\n1725 E CR 875 N\nCamargo, IL 61919   300.0
# ..                                                 ...     ...
# 354  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...   250.0
# 355  Williams, Diana S.\n1901 Golfview\nUrbana, IL ...   200.0
# 356  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...   250.0
# 357  Yarbrough, Roger\n1105 Devonshire Drive\nChamp...   250.0
# 358  Zachary, Monica L.\n598 Pinecrest Place\nRanto...   250.0
#
#     Amount Received Date Report Received Date  \
# 0              9/10/2004            4/21/2005
# 1              11/6/2004            4/21/2005
# 2             10/15/2004            4/21/2005
# 3              3/10/2004             8/2/2004
# 4             10/18/2004            4/21/2005
# ..                   ...                  ...
# 354            2/12/2015            4/14/2015
# 355             8/6/2014            10/1/2014
# 356            9/28/2004            4/21/2005
# 357             8/5/2004            4/21/2005
# 358             2/4/2004             8/2/2004
#
#                                            Received By Description  \
# 0       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 1       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 2       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 3       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# 4       Transfer In\nCitizens for Deborah Frank Feinen         NaN
# ..                                                 ...         ...
# 354  Individual Contribution\nCitizens for Deborah ...         NaN
# 355  Individual Contribution\nCitizens for Deborah ...         NaN
# 356  Individual Contribution\nCitizens for Deborah ...         NaN
# 357  Individual Contribution\nCitizens for Deborah ...         NaN
# 358  Individual Contribution\nCitizens for Deborah ...         NaN
#
#     Vendor Name Vendor Address  Amount received year  Amount received month  \
# 0           NaN            NaN                  2004                      9
# 1           NaN            NaN                  2004                     11
# 2           NaN            NaN                  2004                     10
# 3           NaN            NaN                  2004                      3
# 4           NaN            NaN                  2004                     10
# ..          ...            ...                   ...                    ...
# 354         NaN            NaN                  2015                      2
# 355         NaN            NaN                  2014                      8
# 356         NaN            NaN                  2004                      9
# 357         NaN            NaN                  2004                      8
# 358         NaN            NaN                  2004                      2
#
#      Amount received day  Report received year  Report received month  \
# 0                     10                  2005                      4
# 1                      6                  2005                      4
# 2                     15                  2005                      4
# 3                     10                  2004                      8
# 4                     18                  2005                      4
# ..                   ...                   ...                    ...
# 354                   12                  2015                      4
# 355                    6                  2014                     10
# 356                   28                  2005                      4
# 357                    5                  2005                      4
# 358                    4                  2004                      8
#
#      Report received day                Address  \
# 0                     21          1401 Mesquite
# 1                     21           P.O. Box 396
# 2                     21           P.O. Box 396
# 3                      2           P.O. Box 396
# 4                     21        1725 E CR 875 N
# ..                   ...                    ...
# 354                   14          1901 Golfview
# 355                    1          1901 Golfview
# 356                   21  1105 Devonshire Drive
# 357                   21  1105 Devonshire Drive
# 358                    2    598 Pinecrest Place
#
#                                                  Donor  \
# 0                          15th Congressional District
# 1    A.B.D.I. / PAC (Associated Beer Distributors o...
# 2    A.B.D.I. / PAC (Associated Beer Distributors o...
# 3    A.B.D.I. / PAC (Associated Beer Distributors o...
# 4                                            ABATE PAC
# ..                                                 ...
# 354                                 Williams, Diana S.
# 355                                 Williams, Diana S.
# 356                                   Yarbrough, Roger
# 357                                   Yarbrough, Roger
# 358                                 Zachary, Monica L.
#
#             Report delay months
# 0    {'Report delay months': 7}
# 1    {'Report delay months': 5}
# 2    {'Report delay months': 6}
# 3    {'Report delay months': 5}
# 4    {'Report delay months': 6}
# ..                          ...
# 354  {'Report delay months': 2}
# 355  {'Report delay months': 2}
# 356  {'Report delay months': 7}
# 357  {'Report delay months': 8}
# 358  {'Report delay months': 6}
#
# [359 rows x 17 columns]
